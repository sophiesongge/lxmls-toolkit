# %%
import .lxmls.readers.sentiment_reader as srs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9da20bdce217> in <module>()
# ----> 1 import lxmls.readers.sentiment_reader as srs
#
# ImportError: No module named 'lxmls'
